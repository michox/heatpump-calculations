# %%
wf="R290"

# %% [markdown]
# # Vapor injection heat pump
# The goal of this study is to calculate the impact on COP of multiple injections of vapor into the compressor.
# There are two rationales for this.
# 1. The vapor injection can cool the compressed gas, reducing the energy required for further compression
# 2. The vapor injection can limit the peak temperature to only a few degrees above the condensation temperature, reducing friction and wear on the compressor due to thermal expansion.
#
# In order to achieve most efficient compression, the vapor injection should keep the resulting compression curve as close to the two phase border as possible.
#
# The vapor is not used for subcooling but instead directly merged. The study should also compare the performance of two differnt types of expansion device, namely an expansion valve and a turbine.

# %% [markdown]
# # N=0 no vapor injection

# %%
from HPS_vapor_injection import VaporInjectionHeatPumpStudy
vapor_injection_study = VaporInjectionHeatPumpStudy(working_fluid=wf, N=0, expansion_device="expander"
                                                    ).solve(max_iter=200)
print("COP: ", vapor_injection_study.calculate_cop())
vapor_injection_study.plot_ts_diag("output/multistage_ts_diagram", x_max=3000)
# Out:
# WARNING:root:Reached maximum iteration count (50), calculation stopped. Residual value is 2.78e+02
# ##### RESULTS (Compressor) #####
# +--------------+----------+----------+----------+--------+
# |              |        P |    eta_s |       pr |   igva |
# |--------------+----------+----------+----------+--------|
# | compressor_1 | 4.06e+03 | 8.48e-01 | 7.49e+00 |    nan |
# +--------------+----------+----------+----------+--------+
# ##### RESULTS (Turbine) #####
# +------------+-----------+----------+----------+
# |            |         P |    eta_s |       pr |
# |------------+-----------+----------+----------|
# | expander_1 | -1.10e+03 | 8.50e-01 | 1.39e-01 |
# +------------+-----------+----------+----------+
# ##### RESULTS (CycleCloser) #####
# +--------------+------------------+-------------------+
# |              |   mass_deviation |   fluid_deviation |
# |--------------+------------------+-------------------|
# | cycle_closer |         0.00e+00 |          0.00e+00 |
# +--------------+------------------+-------------------+
# ##### RESULTS (HeatExchangerSimple) #####
# +------------+-----------+----------+----------+-----+-----+------+------+--------+
# |            |         Q |       pr |     zeta |   D |   L |   ks |   kA |   Tamb |
# |------------+-----------+----------+----------+-----+-----+------+------+--------|
# | condenser  | -9.68e+03 | 9.80e-01 | 4.43e+09 | nan | nan |  nan |  nan |    nan |
# | evaporator |  6.72e+03 | 9.80e-01 | 6.55e+07 | nan | nan |  nan |  nan |    nan |
# +------------+-----------+----------+----------+-----+-----+------+------+--------+
# ##### RESULTS (Connection) #####
# +-----+-----------+-----------+-----------+------------+
# |     |         m |         p |         h |          T |
# |-----+-----------+-----------+-----------+------------|
# |   1 | 3.650e-02 | 3.523e+00 | 3.795e+02 | -9.388e+00 |
# |   2 | 3.650e-02 | 3.453e+00 | 5.637e+02 | -1.000e+01 |
# |   4 | 3.650e-02 | 2.587e+01 | 6.749e+02 |  8.500e+01 |
# | 5_3 | 3.650e-02 | 2.535e+01 | 4.098e+02 |  6.897e+01 |
# |   0 | 3.650e-02 | 3.523e+00 | 3.795e+02 | -9.388e+00 |
# +-----+-----------+-----------+-----------+------------+
# <tespy.components.heat_exchangers.simple.HeatExchangerSimple object at 0x000002965920BBD0>
# <tespy.components.turbomachinery.compressor.Compressor object at 0x0000029659204890>
# 4060.340383456422
# <tespy.components.heat_exchangers.simple.HeatExchangerSimple object at 0x0000029659262310>
# <tespy.components.turbomachinery.turbine.Turbine object at 0x0000029659258F10>
# -1104.183687939442
# <tespy.components.basics.cycle_closer.CycleCloser object at 0x0000029659259910>
# COP:  3.2734875289382157

# %% [markdown]
# # N=1 vapor injection after first compression stage

# %%
from HPS_vapor_injection import VaporInjectionHeatPumpStudy
vapor_injection_study = VaporInjectionHeatPumpStudy(working_fluid=wf, N=1, expansion_device="expander"
                                                    ).solve(max_iter=200)
print("COP: ", vapor_injection_study.calculate_cop())
vapor_injection_study.plot_ts_diag("output/multistage_ts_diagram", x_max=3000)
# Out:
# ##### RESULTS (CycleCloser) #####
# +--------------+------------------+-------------------+
# |              |   mass_deviation |   fluid_deviation |
# |--------------+------------------+-------------------|
# | cycle_closer |         0.00e+00 |          0.00e+00 |
# +--------------+------------------+-------------------+
# ##### RESULTS (Turbine) #####
# +------------+-----------+----------+----------+
# |            |         P |    eta_s |       pr |
# |------------+-----------+----------+----------|
# | expander_2 | -9.96e+02 | 8.50e-01 | 2.03e-01 |
# | expander_1 | -2.08e+02 | 8.50e-01 | 5.98e-01 |
# +------------+-----------+----------+----------+
# ##### RESULTS (Compressor) #####
# +--------------+----------+----------+----------+--------+
# |              |        P |    eta_s |       pr |   igva |
# |--------------+----------+----------+----------+--------|
# | compressor_2 | 1.01e+03 | 8.50e-01 | 1.71e+00 |    nan |
# | compressor_1 | 2.94e+03 | 8.50e-01 | 5.04e+00 |    nan |
# +--------------+----------+----------+----------+--------+
# ##### RESULTS (HeatExchangerSimple) #####
# +------------+-----------+----------+----------+-----+-----+------+------+--------+
# |            |         Q |       pr |     zeta |   D |   L |   ks |   kA |   Tamb |
# |------------+-----------+----------+----------+-----+-----+------+------+--------|
# | condenser  | -8.19e+03 | 9.80e-01 | 6.20e+09 | nan | nan |  nan |  nan |    nan |
# | evaporator |  5.45e+03 | 9.80e-01 | 7.85e+07 | nan | nan |  nan |  nan |    nan |
# +------------+-----------+----------+----------+-----+-----+------+------+--------+
# ##### RESULTS (Connection) #####
# +-------+-----------+-----------+-----------+------------+
# |       |         m |         p |         h |          T |
# |-------+-----------+-----------+-----------+------------|
# |     1 | 3.285e-02 | 3.523e+00 | 3.979e+02 | -9.388e+00 |
# |     2 | 3.285e-02 | 3.453e+00 | 5.637e+02 | -1.000e+01 |
# | 3_1_1 | 3.285e-02 | 1.739e+01 | 6.530e+02 |  6.349e+01 |
# | 3_2_1 | 3.650e-02 | 1.739e+01 | 6.305e+02 |  5.407e+01 |
# |     4 | 3.650e-02 | 2.964e+01 | 6.583e+02 |  8.500e+01 |
# |   5_3 | 3.650e-02 | 2.905e+01 | 4.339e+02 |  7.602e+01 |
# | 6_1_1 | 3.650e-02 | 1.739e+01 | 4.282e+02 |  5.067e+01 |
# | 6_2_1 | 3.285e-02 | 1.739e+01 | 4.282e+02 |  5.067e+01 |
# |     0 | 3.285e-02 | 3.523e+00 | 3.979e+02 | -9.388e+00 |
# |   3_1 | 3.650e-03 | 1.739e+01 | 4.282e+02 |  5.067e+01 |
# +-------+-----------+-----------+-----------+------------+
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[6], line 3
#       1 from HPS_vapor_injection import VaporInjectionHeatPumpStudy
#       2 vapor_injection_study = VaporInjectionHeatPumpStudy(working_fluid=wf, N=1, expansion_device="expander"
# ----> 3                                                     ).solve(max_iter=200)
#       4 print("COP: ", vapor_injection_study.calculate_cop())
#       5 vapor_injection_study.plot_ts_diag("output/multistage_ts_diagram", x_max=3000)
#
# File c:\Users\Ilewicz\Desktop\Ecalia CAD\RefrigerantCycle\heatpump-calculations\HeatPumpStudy.py:77, in HeatPumpStudy.solve(self, mode, **args)
#      76 def solve(self, mode="design", **args):
# ---> 77     self.network.solve(mode=mode, design_path="HeatPumpStudy", **args)
#      78     return self
#
# File c:\Users\Ilewicz\AppData\Local\Programs\Python\Python311\Lib\site-packages\tespy\networks\network.py:1653, in Network.solve(self, mode, init_path, design_path, max_iter, min_iter, init_only, init_previous, use_cuda, always_all_equations)
#    1646 msg = (
#    1647     'Network properties: '
#    1648     'number of components=' + str(len(self.comps)) +
#    1649     ', number of connections=' + str(len(self.conns.index)) +
#    1650     ', number of busses=' + str(len(self.busses)))
#    1651 logging.debug(msg)
# -> 1653 self.initialise()
#    1655 if init_only:
#    1656     return
#
# File c:\Users\Ilewicz\AppData\Local\Programs\Python\Python311\Lib\site-packages\tespy\networks\network.py:846, in Network.initialise(self)
#     843     self.init_design()
#     844     # generic fluid initialisation
#     845     # for offdesign cases good starting values should be available
# --> 846     self.init_fluids()
#     848 # generic fluid property initialisation
#     849 self.init_properties()
#
# File c:\Users\Ilewicz\AppData\Local\Programs\Python\Python311\Lib\site-packages\tespy\networks\network.py:1329, in Network.init_fluids(self)
#    1327     if any(c.fluid.val0.values()):
#    1328         c.target.propagate_fluid_to_target(c, c.target)
# -> 1329         c.source.propagate_fluid_to_source(c, c.source)
#    1331 # fluid starting value generation for components
#    1332 for cp in self.comps['object']:
#
# File c:\Users\Ilewicz\AppData\Local\Programs\Python\Python311\Lib\site-packages\tespy\components\nodes\merge.py:365, in Merge.propagate_fluid_to_source(self, outconn, start)
#     361     if (not inconn.fluid.val_set[fluid] and
#     362             not inconn.good_starting_values):
#     363         inconn.fluid.val[fluid] = x
# --> 365 inconn.source.propagate_fluid_to_source(inconn, start)
#
# File c:\Users\Ilewicz\AppData\Local\Programs\Python\Python311\Lib\site-packages\tespy\components\nodes\splitter.py:314, in Splitter.propagate_fluid_to_source(self, outconn, start)
#     310     if (inconn.fluid.val_set[fluid] is False and
#     311             inconn.good_starting_values is False):
#     312         inconn.fluid.val[fluid] = x
# --> 314 inconn.source.propagate_fluid_to_source(inconn, start)
#
# File c:\Users\Ilewicz\AppData\Local\Programs\Python\Python311\Lib\site-packages\tespy\components\component.py:839, in Component.propagate_fluid_to_source(self, outconn, start)
#     835     if (inconn.fluid.val_set[fluid] is False and
#     836             inconn.good_starting_values is False):
#     837         inconn.fluid.val[fluid] = x
# --> 839 inconn.source.propagate_fluid_to_source(inconn, start)
#
# File c:\Users\Ilewicz\AppData\Local\Programs\Python\Python311\Lib\site-packages\tespy\components\component.py:839, in Component.propagate_fluid_to_source(self, outconn, start)
#     835     if (inconn.fluid.val_set[fluid] is False and
#     836             inconn.good_starting_values is False):
#     837         inconn.fluid.val[fluid] = x
# --> 839 inconn.source.propagate_fluid_to_source(inconn, start)
#
#     [... skipping similar frames: Component.propagate_fluid_to_source at line 839 (1 times)]
#
# File c:\Users\Ilewicz\AppData\Local\Programs\Python\Python311\Lib\site-packages\tespy\components\nodes\merge.py:365, in Merge.propagate_fluid_to_source(self, outconn, start)
#     361     if (not inconn.fluid.val_set[fluid] and
#     362             not inconn.good_starting_values):
#     363         inconn.fluid.val[fluid] = x
# --> 365 inconn.source.propagate_fluid_to_source(inconn, start)
#
# File c:\Users\Ilewicz\AppData\Local\Programs\Python\Python311\Lib\site-packages\tespy\components\nodes\splitter.py:314, in Splitter.propagate_fluid_to_source(self, outconn, start)
#     310     if (inconn.fluid.val_set[fluid] is False and
#     311             inconn.good_starting_values is False):
#     312         inconn.fluid.val[fluid] = x
# --> 314 inconn.source.propagate_fluid_to_source(inconn, start)
#
#     [... skipping similar frames: Component.propagate_fluid_to_source at line 839 (1776 times), Merge.propagate_fluid_to_source at line 365 (591 times), Splitter.propagate_fluid_to_source at line 314 (591 times)]
#
# File c:\Users\Ilewicz\AppData\Local\Programs\Python\Python311\Lib\site-packages\tespy\components\nodes\merge.py:365, in Merge.propagate_fluid_to_source(self, outconn, start)
#     361     if (not inconn.fluid.val_set[fluid] and
#     362             not inconn.good_starting_values):
#     363         inconn.fluid.val[fluid] = x
# --> 365 inconn.source.propagate_fluid_to_source(inconn, start)
#
# File c:\Users\Ilewicz\AppData\Local\Programs\Python\Python311\Lib\site-packages\tespy\components\nodes\splitter.py:314, in Splitter.propagate_fluid_to_source(self, outconn, start)
#     310     if (inconn.fluid.val_set[fluid] is False and
#     311             inconn.good_starting_values is False):
#     312         inconn.fluid.val[fluid] = x
# --> 314 inconn.source.propagate_fluid_to_source(inconn, start)
#
#     [... skipping similar frames: Component.propagate_fluid_to_source at line 839 (1 times)]
#
# File c:\Users\Ilewicz\AppData\Local\Programs\Python\Python311\Lib\site-packages\tespy\components\component.py:839, in Component.propagate_fluid_to_source(self, outconn, start)
#     835     if (inconn.fluid.val_set[fluid] is False and
#     836             inconn.good_starting_values is False):
#     837         inconn.fluid.val[fluid] = x
# --> 839 inconn.source.propagate_fluid_to_source(inconn, start)
#
# File c:\Users\Ilewicz\AppData\Local\Programs\Python\Python311\Lib\site-packages\tespy\components\component.py:834, in Component.propagate_fluid_to_source(self, outconn, start)
#     831 conn_idx = self.outl.index(outconn)
#     832 inconn = self.inl[conn_idx]
# --> 834 for fluid, x in outconn.fluid.val.items():
#     835     if (inconn.fluid.val_set[fluid] is False and
#     836             inconn.good_starting_values is False):
#     837         inconn.fluid.val[fluid] = x
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %% [markdown]
# # N=3 vapor injection after first compression stage

# %%
from HPS_vapor_injection import VaporInjectionHeatPumpStudy
vapor_injection_study = VaporInjectionHeatPumpStudy(working_fluid=wf, N=3, expansion_device="expander"
                                                    ).solve(max_iter=200)
print("COP: ", vapor_injection_study.calculate_cop())
vapor_injection_study.plot_ts_diag("output/multistage_ts_diagram", x_max=3000)
# Out:
# WARNING:root:The starting value for the fluid composition of the connection 3_2_3 is empty. This might lead to issues in the initialisation and solving process as fluid property functions can not be called. Make sure you specified a fluid composition in all parts of the network.
# WARNING:root:The starting value for the fluid composition of the connection 4 is empty. This might lead to issues in the initialisation and solving process as fluid property functions can not be called. Make sure you specified a fluid composition in all parts of the network.
# WARNING:root:The starting value for the fluid composition of the connection 5_3 is empty. This might lead to issues in the initialisation and solving process as fluid property functions can not be called. Make sure you specified a fluid composition in all parts of the network.
# WARNING:root:The starting value for the fluid composition of the connection 6_1_1 is empty. This might lead to issues in the initialisation and solving process as fluid property functions can not be called. Make sure you specified a fluid composition in all parts of the network.
# WARNING:root:The starting value for the fluid composition of the connection 6_2_1 is empty. This might lead to issues in the initialisation and solving process as fluid property functions can not be called. Make sure you specified a fluid composition in all parts of the network.
# WARNING:root:The starting value for the fluid composition of the connection 6_1_2 is empty. This might lead to issues in the initialisation and solving process as fluid property functions can not be called. Make sure you specified a fluid composition in all parts of the network.
# WARNING:root:The starting value for the fluid composition of the connection 6_2_2 is empty. This might lead to issues in the initialisation and solving process as fluid property functions can not be called. Make sure you specified a fluid composition in all parts of the network.
# WARNING:root:The starting value for the fluid composition of the connection 6_1_3 is empty. This might lead to issues in the initialisation and solving process as fluid property functions can not be called. Make sure you specified a fluid composition in all parts of the network.
# WARNING:root:The starting value for the fluid composition of the connection 6_2_3 is empty. This might lead to issues in the initialisation and solving process as fluid property functions can not be called. Make sure you specified a fluid composition in all parts of the network.
# WARNING:root:The starting value for the fluid composition of the connection 0 is empty. This might lead to issues in the initialisation and solving process as fluid property functions can not be called. Make sure you specified a fluid composition in all parts of the network.
# WARNING:root:The starting value for the fluid composition of the connection 3_3 is empty. This might lead to issues in the initialisation and solving process as fluid property functions can not be called. Make sure you specified a fluid composition in all parts of the network.
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 from HPS_vapor_injection import VaporInjectionHeatPumpStudy
# ----> 2 vapor_injection_study = VaporInjectionHeatPumpStudy(working_fluid=wf, N=3, expansion_device="expander"
#       3                                                     ).solve(max_iter=200)
#       4 print("COP: ", vapor_injection_study.calculate_cop())
#       5 vapor_injection_study.plot_ts_diag("output/multistage_ts_diagram", x_max=3000)
#
# File c:\Users\Ilewicz\Desktop\Ecalia CAD\RefrigerantCycle\heatpump-calculations\HPS_vapor_injection.py:19, in VaporInjectionHeatPumpStudy.__init__(self, **kwargs)
#      18 def __init__(self, **kwargs):
# ---> 19     super().__init__(**kwargs)
#
# File c:\Users\Ilewicz\Desktop\Ecalia CAD\RefrigerantCycle\heatpump-calculations\HeatPumpStudy.py:44, in HeatPumpStudy.__init__(self, N, Q_out, working_fluid, compressor_efficiency, expander_efficiency, expansion_device)
#      42 self.conn: Dict[str, Connection] = {}
#      43 self.network = None
# ---> 44 self.setup_network()
#
# File c:\Users\Ilewicz\Desktop\Ecalia CAD\RefrigerantCycle\heatpump-calculations\HeatPumpStudy.py:56, in HeatPumpStudy.setup_network(self, iterinfo)
#      54 self.setup_components_and_connections()
#      55 self.network.add_conns(*list(self.conn.values()))
# ---> 56 self.set_boundary_conditions()
#      57 return self
#
# File c:\Users\Ilewicz\Desktop\Ecalia CAD\RefrigerantCycle\heatpump-calculations\HPS_vapor_injection.py:104, in VaporInjectionHeatPumpStudy.set_boundary_conditions(self, T_cond, T_evap)
#     101         self.conn[conn].set_attr(p=p)
#     102         self.conn[conn].set_attr(m=m0/10/(self.N))
# --> 104 self.solve()
#     105 self.network.print_results()
#     108 for conn in self.conn:
#
# File c:\Users\Ilewicz\Desktop\Ecalia CAD\RefrigerantCycle\heatpump-calculations\HeatPumpStudy.py:77, in HeatPumpStudy.solve(self, mode, **args)
#      76 def solve(self, mode="design", **args):
# ---> 77     self.network.solve(mode=mode, design_path="HeatPumpStudy", **args)
#      78     return self
#
# File c:\Users\Ilewicz\AppData\Local\Programs\Python\Python311\Lib\site-packages\tespy\networks\network.py:1653, in Network.solve(self, mode, init_path, design_path, max_iter, min_iter, init_only, init_previous, use_cuda, always_all_equations)
#    1646 msg = (
#    1647     'Network properties: '
#    1648     'number of components=' + str(len(self.comps)) +
#    1649     ', number of connections=' + str(len(self.conns.index)) +
#    1650     ', number of busses=' + str(len(self.busses)))
#    1651 logging.debug(msg)
# -> 1653 self.initialise()
#    1655 if init_only:
#    1656     return
#
# File c:\Users\Ilewicz\AppData\Local\Programs\Python\Python311\Lib\site-packages\tespy\networks\network.py:849, in Network.initialise(self)
#     846     self.init_fluids()
#     848 # generic fluid property initialisation
# --> 849 self.init_properties()
#     851 msg = 'Network initialised.'
#     852 logging.info(msg)
#
# File c:\Users\Ilewicz\AppData\Local\Programs\Python\Python311\Lib\site-packages\tespy\networks\network.py:1412, in Network.init_properties(self)
#    1405         if (c.get_attr(key).ref_set and
#    1406                 not c.get_attr(key).val_set):
#    1407             c.get_attr(key).val_SI = (
#    1408                     c.get_attr(key).ref.obj.get_attr(key).val_SI *
#    1409                     c.get_attr(key).ref.factor +
#    1410                     c.get_attr(key).ref.delta_SI)
# -> 1412     self.init_precalc_properties(c)
#    1414 # starting values for specified subcooling/overheating
#    1415 # and state specification. These should be recalculated even with
#    1416 # good starting values, for example, when one exchanges enthalpy
#    1417 # with boiling point temperature difference.
#    1418 if ((c.Td_bp.val_set or c.state.is_set) and
#    1419         not c.h.val_set):
#
# File c:\Users\Ilewicz\AppData\Local\Programs\Python\Python311\Lib\site-packages\tespy\networks\network.py:1487, in Network.init_precalc_properties(self, c)
#    1485 if c.T.val_set and not c.h.val_set:
#    1486     try:
# -> 1487         c.h.val_SI = fp.h_mix_pT(c.get_flow(), c.T.val_SI)
#    1488     except ValueError:
#    1489         pass
#
# File c:\Users\Ilewicz\AppData\Local\Programs\Python\Python311\Lib\site-packages\tespy\tools\fluid_properties.py:535, in h_mix_pT(flow, T, force_gas)
#     532 fluid_name = single_fluid(flow[3])
#     533 if fluid_name is None:
# --> 535     x_i = {
#     536         fluid: y / (molar_masses[fluid] * n)
#     537         for fluid, y in flow[3].items()
#     538     }
#     540     water = Memorise.water
#     541     if (water is not None and not force_gas and flow[3][water] > err):
#
# File c:\Users\Ilewicz\AppData\Local\Programs\Python\Python311\Lib\site-packages\tespy\tools\fluid_properties.py:536, in <dictcomp>(.0)
#     532 fluid_name = single_fluid(flow[3])
#     533 if fluid_name is None:
#     535     x_i = {
# --> 536         fluid: y / (molar_masses[fluid] * n)
#     537         for fluid, y in flow[3].items()
#     538     }
#     540     water = Memorise.water
#     541     if (water is not None and not force_gas and flow[3][water] > err):
#
# ZeroDivisionError: float division by zero
