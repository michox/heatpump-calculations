# %%
wf="R290"

# %% [markdown]
# # Vapor injection heat pump
# The goal of this study is to calculate the impact on COP of multiple injections of vapor into the compressor.
# There are two rationales for this.
# 1. The vapor injection can cool the compressed gas, reducing the energy required for further compression
# 2. The vapor injection can limit the peak temperature to only a few degrees above the condensation temperature, reducing friction and wear on the compressor.
#
# In order to achieve most efficient compression, the vapor injection should keep the resulting compression curve as close to the two phase border as possible.
#
# The vapor is not used for subcooling but instead directly merged. The study should also compare the performance of two differnt types of expansion device, namely an expansion valve and a turbine.

# %% [markdown]
# # N=0 no vapor injection

# %%
from VaporInjectionHeatPumpStudy import VaporInjectionHeatPumpStudy
vapor_injection_study = VaporInjectionHeatPumpStudy(working_fluid=wf, N=0, expansion_device="expander"
                                                    ).solve(max_iter=200)
print("COP: ", vapor_injection_study.calculate_cop())
vapor_injection_study.plot_ts_diag("output/multistage_ts_diagram", x_max=3000)

# %% [markdown]
# # N=1 vapor injection after first compression stage

# %%
from VaporInjectionHeatPumpStudy import VaporInjectionHeatPumpStudy
vapor_injection_study = VaporInjectionHeatPumpStudy(working_fluid=wf, N=1, expansion_device="expander"
                                                    ).solve(max_iter=200)
print("COP: ", vapor_injection_study.calculate_cop())
vapor_injection_study.plot_ts_diag("output/multistage_ts_diagram", x_max=3000)
# Out:
# ERROR:root:Singularity in jacobian matrix, calculation aborted! Make sure your network does not have any linear dependencies in the parametrisation. Other reasons might be
# -> given temperature with given pressure in two phase region, try setting enthalpy instead or provide accurate starting value for pressure.
# -> given logarithmic temperature differences or kA-values for heat exchangers,
# -> support better starting values.
# -> bad starting value for fuel mass flow of combustion chamber, provide small (near to zero, but not zero) starting value.
# COP:  4000.0
# ---------------------------------------------------------------------------
#
# ValueError                                Traceback (most recent call last)
#
# Cell In[5], line 7
#
#       4 print("COP: ", vapor_injection_study.calculate_cop())
#
#       5 #multistage_study.print_connections()
#
#       6 #multistage_study.plot_logph_diag("output/multistage_logph_diagram")
#
# ----> 7 vapor_injection_study.plot_ts_diag("output/multistage_ts_diagram", x_max=3000)
#
#
#
# File c:\Users\Ilewicz\Desktop\Ecalia CAD\RefrigerantCycle\heatpump-calculations\HeatPumpStudy.py:223, in HeatPumpStudy.plot_ts_diag(self, filename, x_min, x_max, y_min, y_max)
#
#     221 result_dict = self.get_results()
#
#     222 for key, data in result_dict.items():
#
# --> 223     result_dict[key]["datapoints"] = diagram.calc_individual_isoline(**data)
#
#     225 diagram.set_limits(x_min=x_min, x_max=x_max, y_min=y_min, y_max=y_max)
#
#     226 T = np.arange(-50, 101, 5)
#
#
#
# File c:\Users\Ilewicz\AppData\Local\Programs\Python\Python311\Lib\site-packages\fluprodia\fluid_property_diagram.py:790, in FluidPropertyDiagram.calc_individual_isoline(self, isoline_property, isoline_value, isoline_value_end, starting_point_property, ending_point_property, starting_point_value, ending_point_value)
#
#     788     density_start = starting_point_value
#
#     789 else:
#
# --> 790     density_start = CP.CoolProp.PropsSI(
#
#     791         'D', starting_point_property.upper(),
#
#     792         starting_point_value, isoline_property.upper(),
#
#     793         isoline_value, self.fluid
#
#     794     )
#
#     796 if ending_point_property == 'D':
#
#     797     density_end = ending_point_value
#
#
#
# File CoolProp\CoolProp.pyx:384, in CoolProp.CoolProp.PropsSI()
#
#
#
# File CoolProp\CoolProp.pyx:464, in CoolProp.CoolProp.PropsSI()
#
#
#
# File CoolProp\CoolProp.pyx:351, in CoolProp.CoolProp.__Props_err2()
#
#
#
# ValueError: The pressure [nan Pa] cannot be used in p_phase_determination : PropsSI("D","S",nan,"P",nan,"R290")
